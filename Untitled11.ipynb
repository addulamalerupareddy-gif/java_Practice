# %% [markdown]
# <a href="https://colab.research.google.com/github/addulamalerupareddy-gif/java_Practice/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 04/09

# %%
import numpy as np
import pandas as pd

# %%
data1=pd.read_csv(r'/content/employees (2).csv')
data1
# Out:
#      First Name  Gender Start Date    Salary   Mgmt          Team
# 0       Douglas    Male     8/6/93       NaN   True     Marketing
# 1        Thomas    Male    3/31/96   61933.0   True           NaN
# 2         Maria  Female        NaN  130590.0  False       Finance
# 3         Jerry     NaN     3/4/05  138705.0   True       Finance
# 4         Larry    Male    1/24/98  101004.0   True            IT
# ...         ...     ...        ...       ...    ...           ...
# 996     Phillip    Male    1/31/84   42392.0  False       Finance
# 997     Russell    Male    5/20/13   96914.0  False       Product
# 998       Larry    Male    4/20/13   60500.0  False  Business Dev
# 999      Albert    Male    5/15/12  129949.0   True         Sales
# 1000        NaN     NaN        NaN       NaN    NaN           NaN
#
# [1001 rows x 6 columns]

# %% [markdown]
# drop the row having NANsin the firstname variable

# %%
data1.isna().sum()
# Out:
# First Name     68
# Gender        147
# Start Date      2
# Salary          2
# Mgmt           68
# Team           44
# dtype: int64

# %%
data1.shape
# Out:
# (1001, 6)

# %% [markdown]
# dropna() create a copy to save the modication
#
# -data.dropna(how='any',subset=['first time'],inplace=True

# %%
data1.isna().sum()
# Out:
# First Name     68
# Gender        147
# Start Date      2
# Salary          2
# Mgmt           68
# Team           44
# dtype: int64

# %% [markdown]
# fill the missing values in gender column
#
# .categorical -mode

# %%
data1.Gender.mode()
# Out:
# 0    Female
# Name: Gender, dtype: object

# %%
data1.Gender.mode()[0]
# Out:
# 'Female'

# %% [markdown]
# to fill  the missing value use method 'fillna()
#
# -for a series
#
# series.fillna(col_umn=fill_value)
#
# -for a dataframe.fillna({col_name1=fill_value1,col_name2:fill_value2,col_name3:fill_value3 .....}0

# %%
data1.Gender
# Out:
# 0         Male
# 1         Male
# 2       Female
# 3          NaN
# 4         Male
#          ...
# 996       Male
# 997       Male
# 998       Male
# 999       Male
# 1000       NaN
# Name: Gender, Length: 1001, dtype: object

# %%
data1.Gender.fillna(data1.Gender.mode()[0])
# Out:
# 0         Male
# 1         Male
# 2       Female
# 3       Female
# 4         Male
#          ...
# 996       Male
# 997       Male
# 998       Male
# 999       Male
# 1000    Female
# Name: Gender, Length: 1001, dtype: object

# %%
data1.Gender.fillna(data1.Gender.mode()[0]).isna().sum()
# Out:
# np.int64(0)

# %%
data1.isna().sum()
# Out:
# First Name     68
# Gender        147
# Start Date      2
# Salary          2
# Mgmt           68
# Team           44
# dtype: int64

# %%
data1.Gender=data1.Gender.fillna(data1.Gender.mode()[0])

# %%
data1.isna().sum()
# Out:
# First Name    68
# Gender         0
# Start Date     2
# Salary         2
# Mgmt          68
# Team          44
# dtype: int64

# %% [markdown]
# fill missing values in team variable
#
#
# -categorical variable
#
# -mode

# %%
data1.Team.mode()
# Out:
# 0    IT
# Name: Team, dtype: object

# %%
data1.Team.mode()[0]
# Out:
# 'IT'

# %% [markdown]
# fill the missing values in salary data
#
# -continous numeric variable
#
# -mean or median
#
# -decide among mean and median-based on outlier
#
# -how to detect outliers
#
# .IQR
#
# .Boxplot

# %%
data1.Salary.head()
# Out:
# 0         NaN
# 1     61933.0
# 2    130590.0
# 3    138705.0
# 4    101004.0
# Name: Salary, dtype: float64

# %%
'quantile'in dir(data1.Salary)
# Out:
# True

# %%
q1=data1.Salary.quantile(0.25)
q1
# Out:
# np.float64(62560.0)

# %%
q2=data1.Salary.quantile(0.50)
q2
# Out:
# np.float64(90427.0)

# %%
q2=data1.Salary.median()
q2
# Out:
# 90427.0

# %%
q3=data1.Salary.quantile(0.75)
q3
# Out:
# np.float64(118744.5)

# %%
iqr=q3-q1
iqr
# Out:
# np.float64(56184.5)

# %%
u1=q3 +1.5*iqr
u1
# Out:
# np.float64(203021.25)

# %% [markdown]
# potential outliers are values
#
# .either<ll
#
# .or >ul

# %%
#values not between 11 and
data1[(data1.Salary <11) |(data1.Salary >u1)]
# Out:
# Empty DataFrame
# Columns: [First Name, Gender, Start Date, Salary, Mgmt, Team]
# Index: []

# %%
data1.Salary.plot(kind = 'box', figsize = (4,3)) # defalut size is 640p x 480px
# Out:
# <Axes: >

# %%
data1.Salary.mean()
# Out:
# np.float64(90655.52852852854)

# %%
mean_sal = np.round(data1.Salary.mean(),2 )
mean_sal
# Out:
# np.float64(90655.53)

# %%
data1.isna().sum()
# Out:
# First Name    68
# Gender         0
# Start Date     2
# Salary         2
# Mgmt          68
# Team          44
# dtype: int64

# %%
# %%writefile data2.csv
# c1,c2,c3
# 1,2,3
# 4,5,6
# 1,2,3
# 4,5,6
# 7,8,9
# Out:
# Overwriting data2.csv

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First Name  933 non-null    object
#  1   Gender      1001 non-null   object
#  2   Start Date  999 non-null    object
#  3   Salary      999 non-null    float64
#  4   Mgmt        933 non-null    object
#  5   Team        957 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 47.1+ KB
