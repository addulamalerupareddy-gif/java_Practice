# %% [markdown]
# <a href="https://colab.research.google.com/github/addulamalerupareddy-gif/java_Practice/blob/main/Task_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name='sai'
print(name)
# Out:
# sai

# %%
age='22'
print(age)
# Out:
# 22

# %%
a='sai'
b='kumar'
print(a,b)
# Out:
# sai kumar

# %%
a=10
b=20
sum=(a+b)
print(sum)
# Out:
# 30

# %%
a=2.5
b=4
product=(a*b)
print(product)
# Out:
# 10.0

# %%
a=5
b=10
print(b,a)
# Out:
# 10 5

# %%
a=250
b=4
product=(a*b)
print(product)
# Out:
# 1000

# %%
a='python'
print(type(a))
# Out:
# <class 'str'>

# %%
storeint=10
float=2.5
string='hello'
bool=True
print(type(storeint))
print(type(float))
print(type(string))
print(type(bool))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
a=80
b=90
c=70
average=(a+b+c)/3
print(average)
# Out:
# 80.0

# %%
a=15
b=20
sum=(a+b)
print(sum)
# Out:
# 35

# %%
a=20
b=8
sub=(a-b)
print(sub)
# Out:
# 12

# %%
a=12
b=5
mul=(a*b)
print(mul)
# Out:
# 60

# %%
a=20
b=4
div=(a/b)
print(div)
# Out:
# 5.0

# %%
a=20
b=6
floordiv=(a//b)
print(floordiv)
# Out:
# 3

# %%
a=20
b=6
modulus=(a%b)
print(modulus)
# Out:
# 2

# %%
a=2
b=5
power=(a**b)
print(power)
# Out:
# 32

# %%
a=15
b=20
a>b
# Out:
# False

# %%
a=35
print(a%5==0)
# Out:
# True

# %%
l=10
b=8
area=(l*b)
print(area)
# Out:
# 80

# %% [markdown]
# strings

# %%
a='python'
print(a)
# Out:
# python

# %%
a='programming'
print(len(a))
# Out:
# 11

# %%
a='python'
a.upper()
# Out:
# 'PYTHON'

# %%
a='python'
a.lower()
# Out:
# 'python'

# %%
a='hello world'
a.capitalize()
# Out:
# 'Hello world'

# %%
a='hello python world'
print(a.count(" "))
# Out:
# 2

# %%
a='python'
print(a[::-1])
# Out:
# nohtyp

# %%
a='hello python'
a.replace(' ','_')
# Out:
# 'hello_python'

# %%
a='banana'
a.count('a')
# Out:
# 3

# %%
a='python'
a.strip()
# Out:
# 'python'

# %% [markdown]
# string funtion

# %%
a='python'
print(a.startswith('py'))
# Out:
# True

# %%
a='program.py'
print(a.endswith('py'))
# Out:
# True

# %%
a='python is easy'
a.split(' ')
# Out:
# ['python', 'is', 'easy']

# %%
a=['python','is','fun']
b="-".join(a)
print(b)
# Out:
# python-is-fun

# %%
a='python'
a.isalpha()
# Out:
# True

# %%
a='12345'
a.isdigit()
# Out:
# True

# %%
a='programming'
a.index('g')
# Out:
# 3

# %%
a='hi'
b=a*3
print(b)
# Out:
# hihihi

# %%
a='python is very easy'
b=a.split()
print(len(b))
# Out:
# 4

# %%
a='python'
a[0]
# Out:
# 'p'

# %%
a='python'
a[-1]
# Out:
# 'n'

# %%
a='python'
a[1]
# Out:
# 'y'

# %%
a='python'
a[3]
# Out:
# 'h'

# %%
a='programming'
print(a[0],a[-1])
# Out:
# p g

# %%
a='programming'
print(a[5])
# Out:
# a

# %%
a='python'
print(a[3])
# Out:
# h

# %%
a='pythonic'
length=len(a)
b = length//2
print(a[b-1])
# Out:
# h

# %%
a='code'
b=a.upper()
print(b[0],b[1],b[2],b[3])
# Out:
# C O D E

# %%
a='code'
b=a.upper()
print(b[3],b[2],b[1],b[0])
# Out:
# E D O C

# %% [markdown]
# slicing

# %%
a='programming'
a[0:5]
# Out:
# 'progr'

# %%
a='programming'
a[7:]
# Out:
# 'ming'

# %%
a='programming'
a[2:7]
# Out:
# 'ogram'

# %%
a='programming'
a[::2]
# Out:
# 'pormig'

# %%
a='python'
a[::-1]
# Out:
# 'nohtyp'

# %%
a='python'
a[1::1]
# Out:
# 'ython'

# %%
a='python'
a[:5:1]
# Out:
# 'pytho'

# %%
a='programmimg'
a[:5:1]
# Out:
# 'progr'

# %%
a='programming'
a[5::1]
# Out:
# 'amming'

# %%
a='programming'
a[::-2]
# Out:
# 'gimrop'
