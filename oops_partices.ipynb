# %% [markdown]
# <a href="https://colab.research.google.com/github/addulamalerupareddy-gif/java_Practice/blob/main/oops_partices.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class student:
  name="rupa"
s1=student()
print(s1.name)
# Out:
# rupa

# %%
class student:
  name="shilaja"
s1=student()
print(s1.name)
# Out:
# shilaja

# %%
class student:
  def __init__(self,name,age):
    self.name=name
    self.age=age
s1=student('rupa',21)
print(s1.name)
print(s1.age)
# Out:
# rupa
# 21

# %%
class student:
 def __init__(self,name,age):
  self.name=name
  self.age=age
s1=student('rupa',21)
print(s1.name)
print(s1.age)
# Out:
# rupa
# 21

# %%
class student:
  def display(self):
    print('welco')
s1=student()
s1.display()
# Out:
# welco

# %%
class student:
  def display(self):
    print("jhj")
s1=student()
s1.display()
print("jhj")
# Out:
# jhj
# jhj

# %%
class bank:
  def __init__(self):
    self.balance=5000
  def show_balance(self):
    print('balance:',self.balance)
b=bank()
b.show_balance()
# Out:
# balance: 5000

# %%
class student:
  def __init__(self,name,rollno):
    self.name=name
    self.rollno=rollno
  def display(self):
    print('name:',self.name)
    print('rollno:',self.rollno)
s1=student('rupa',12)
s1.display()
# Out:
# name: rupa
# rollno: 12

# %%
class employee:
  def __init__(self,name,salary):
    self.name=name
    self.salary=salary
  def display(self):
    print('name:',self.name)
    print('employee:',self.salary)
s1=employee('rupa',100000)
s1.display()
# Out:
# name: rupa
# employee: 100000

# %%
class rectangle:
  def __init__(self,length,width):
    self.length=length
    self.width=width
  def area(self):
    print('area=',self.length*self.width)
r=rectangle(10,5)
r.area()
# Out:
# area= 50
