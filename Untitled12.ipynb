# %% [markdown]
# <a href="https://colab.research.google.com/github/addulamalerupareddy-gif/java_Practice/blob/main/Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 07/09

# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv(r'/content/cleaned_emp_data.csv')
data
# Out:
#      Unnamed: 0 First Name  Gender Start Date     Salary   Mgmt          Team
# 0             0    Douglas    Male     8/6/93   90281.27   True     Marketing
# 1             1     Thomas    Male    3/31/96   61933.00   True            IT
# 2             3      Jerry  Female     3/4/05  138705.00   True       Finance
# 3             4      Larry    Male    1/24/98  101004.00   True            IT
# 4             5     Dennis    Male    4/18/87  115163.00  False         Legal
# ..          ...        ...     ...        ...        ...    ...           ...
# 927         995      Henry  Female   11/23/14  132483.00  False  Distribution
# 928         996    Phillip    Male    1/31/84   42392.00  False       Finance
# 929         997    Russell    Male    5/20/13   96914.00  False       Product
# 930         998      Larry    Male    4/20/13   60500.00  False  Business Dev
# 931         999     Albert    Male    5/15/12  129949.00   True         Sales
#
# [932 rows x 7 columns]

# %%
data.isna().sum()
# Out:
# Unnamed: 0    0
# First Name    0
# Gender        0
# Start Date    0
# Salary        0
# Mgmt          0
# Team          0
# dtype: int64

# %% [markdown]
# person with name marla
#
# ..belong to departments-product,hr,legal
#
# .one person belong to product department holds managerical role

# %%
data.head()
# Out:
#    Unnamed: 0 First Name  Gender Start Date     Salary   Mgmt       Team
# 0           0    Douglas    Male     8/6/93   90281.27   True  Marketing
# 1           1     Thomas    Male    3/31/96   61933.00   True         IT
# 2           3      Jerry  Female     3/4/05  138705.00   True    Finance
# 3           4      Larry    Male    1/24/98  101004.00   True         IT
# 4           5     Dennis    Male    4/18/87  115163.00  False      Legal

# %%
data.Team.unique()
# Out:
# array(['Marketing', 'IT', 'Finance', 'Legal', 'Product', 'Engineering',
#        'Business Dev', 'HR', 'Sales', 'Distribution'], dtype=object)

# %% [markdown]
# exact info about finance

# %%
data.Team=='Finance'
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 927    True
# 928    True
# 929    True
# 930    True
# 931    True
# Name: Team, Length: 932, dtype: bool

# %%
fin_dept=data[data.Team=='Finance']
fin_dept
# Out:
#      Unnamed: 0 First Name  Gender Start Date     Salary   Mgmt     Team
# 0             0    Douglas    Male     8/6/93   90281.27   True  Finance
# 1             1     Thomas    Male    3/31/96   61933.00   True  Finance
# 2             3      Jerry  Female     3/4/05  138705.00   True  Finance
# 3             4      Larry    Male    1/24/98  101004.00   True  Finance
# 4             5     Dennis    Male    4/18/87  115163.00  False  Finance
# ..          ...        ...     ...        ...        ...    ...      ...
# 927         995      Henry  Female   11/23/14  132483.00  False  Finance
# 928         996    Phillip    Male    1/31/84   42392.00  False  Finance
# 929         997    Russell    Male    5/20/13   96914.00  False  Finance
# 930         998      Larry    Male    4/20/13   60500.00  False  Finance
# 931         999     Albert    Male    5/15/12  129949.00   True  Finance
#
# [932 rows x 7 columns]

# %%
fin_dept['Gender'].value_counts()
# Out:
# Gender
# Female    538
# Male      394
# Name: count, dtype: int64

# %%
fin_dept['Mgmt'].value_counts()
# Out:
# Mgmt
# True     468
# False    464
# Name: count, dtype: int64

# %% [markdown]
# for any categorical variable,to find the distribition use-value_counts()

# %%
#all departments employee distribution
for dept in data.Team.unique():
 print('Department: ',dept)
 data[data.Team== dept]
# Out:
# Department:  Finance

# %%
for dept in data.Team.unique():
 print('Department: ',dept)
 data[data.Team== dept]
 print('Gender Distribution:', data.loc[data.Team==dept,'Gender'].value_counts())
 print('\n')
# Out:
# Department:  Finance
# Gender Distribution: Gender
# Female    538
# Male      394
# Name: count, dtype: int64

# %% [markdown]
# -other than HR department in all the other departments,number of female employees are more
#
# -like most of the department in finance department
#
# .number of female employees are more and
#
# .number of managers are more

# %% [markdown]
# what proportion of employees in finance hold

# %%
fin_dept
# Out:
#      Unnamed: 0 First Name  Gender Start Date     Salary   Mgmt     Team
# 0             0    Douglas    Male     8/6/93   90281.27   True  Finance
# 1             1     Thomas    Male    3/31/96   61933.00   True  Finance
# 2             3      Jerry  Female     3/4/05  138705.00   True  Finance
# 3             4      Larry    Male    1/24/98  101004.00   True  Finance
# 4             5     Dennis    Male    4/18/87  115163.00  False  Finance
# ..          ...        ...     ...        ...        ...    ...      ...
# 927         995      Henry  Female   11/23/14  132483.00  False  Finance
# 928         996    Phillip    Male    1/31/84   42392.00  False  Finance
# 929         997    Russell    Male    5/20/13   96914.00  False  Finance
# 930         998      Larry    Male    4/20/13   60500.00  False  Finance
# 931         999     Albert    Male    5/15/12  129949.00   True  Finance
#
# [932 rows x 7 columns]

# %%
fin_dept['Mgmt'].value_counts()
# Out:
# Mgmt
# True     468
# False    464
# Name: count, dtype: int64

# %%
fin_dept['Mgmt'].value_counts(normalize=True)
# Out:
# Mgmt
# True     0.502146
# False    0.497854
# Name: proportion, dtype: float64

# %% [markdown]
# -48% of employees in finance department holds mangerial roles

# %% [markdown]
# **what are the characteristics of employees earing $100,000 or more?**
#
# -male vs female
#
# -Managerial or non Managerial
#
# -which dept employees are more in salary $100000?

# %%
high_salary=data[data['Salary']>=100000]
high_salary
# Out:
#      Unnamed: 0 First Name  Gender Start Date    Salary   Mgmt     Team
# 2             3      Jerry  Female     3/4/05  138705.0   True  Finance
# 3             4      Larry    Male    1/24/98  101004.0   True  Finance
# 4             5     Dennis    Male    4/18/87  115163.0  False  Finance
# 7             9    Frances  Female     8/8/02  139852.0   True  Finance
# 9            11      Julie  Female   10/26/97  102508.0   True  Finance
# ..          ...        ...     ...        ...       ...    ...      ...
# 922         990      Robin  Female    7/24/87  100765.0   True  Finance
# 923         991       Rose  Female    8/25/02  134505.0   True  Finance
# 924         992    Anthony    Male   10/16/11  112769.0   True  Finance
# 927         995      Henry  Female   11/23/14  132483.0  False  Finance
# 931         999     Albert    Male    5/15/12  129949.0   True  Finance
#
# [376 rows x 7 columns]

# %%
high_salary['Gender'].value_counts()
# Out:
# Gender
# Female    215
# Male      161
# Name: count, dtype: int64

# %%
high_salary['Mgmt'].value_counts()
# Out:
# Mgmt
# True     195
# False    181
# Name: count, dtype: int64

# %%
high_salary['Team'].value_counts()
# Out:
# Team
# Finance    376
# Name: count, dtype: int64

# %% [markdown]
# **how does gender representation affect business development team composition?**
#
# .proportion of male and female in the business development team

# %%
data.Team.unique()
# Out:
# array(['Finance'], dtype=object)

# %%
fin_dept
# Out:
#      Unnamed: 0 First Name  Gender Start Date     Salary   Mgmt     Team
# 0             0    Douglas    Male     8/6/93   90281.27   True  Finance
# 1             1     Thomas    Male    3/31/96   61933.00   True  Finance
# 2             3      Jerry  Female     3/4/05  138705.00   True  Finance
# 3             4      Larry    Male    1/24/98  101004.00   True  Finance
# 4             5     Dennis    Male    4/18/87  115163.00  False  Finance
# ..          ...        ...     ...        ...        ...    ...      ...
# 927         995      Henry  Female   11/23/14  132483.00  False  Finance
# 928         996    Phillip    Male    1/31/84   42392.00  False  Finance
# 929         997    Russell    Male    5/20/13   96914.00  False  Finance
# 930         998      Larry    Male    4/20/13   60500.00  False  Finance
# 931         999     Albert    Male    5/15/12  129949.00   True  Finance
#
# [932 rows x 7 columns]

# %%
data.Team=='Bussiness Dev'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 927    False
# 928    False
# 929    False
# 930    False
# 931    False
# Name: Team, Length: 932, dtype: bool

# %%
bd_team=data.loc[data.Team== 'Bussiness Dev']
bd_team
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, First Name, Gender, Start Date, Salary, Mgmt, Team]
# Index: []

# %%
bd_team=data.loc[data.Team=='Bussiness Dev','Gender'].value_counts(normalize=True)
bd_team
# Out:
# Series([], Name: proportion, dtype: float64)

# %% [markdown]
# in the business dev team the proportion of female employees in high

# %%
bd_team['Mgmt'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %% [markdown]
# what trends emerge among employees earing below $40,000 or those hired after january 1,2015?**
#
# -what are the characteristics of recently joined employess

# %%
(data['Salary']<4000)|(data['Start Date']>'2015-01-01')
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4       True
#        ...
# 927    False
# 928    False
# 929     True
# 930     True
# 931     True
# Length: 932, dtype: bool

# %%
recent_emp=data[(data['Salary']<4000)|(data['Start Date']>'2015-01-01')]
recent_emp
# Out:
#      Unnamed: 0 First Name  Gender Start Date     Salary   Mgmt     Team
# 0             0    Douglas    Male     8/6/93   90281.27   True  Finance
# 1             1     Thomas    Male    3/31/96   61933.00   True  Finance
# 2             3      Jerry  Female     3/4/05  138705.00   True  Finance
# 4             5     Dennis    Male    4/18/87  115163.00  False  Finance
# 5             6       Ruby  Female    8/17/87   65476.00   True  Finance
# ..          ...        ...     ...        ...        ...    ...      ...
# 925         993       Tina  Female    5/15/97   56450.00   True  Finance
# 926         994     George    Male    6/21/13   98874.00   True  Finance
# 929         997    Russell    Male    5/20/13   96914.00  False  Finance
# 930         998      Larry    Male    4/20/13   60500.00  False  Finance
# 931         999     Albert    Male    5/15/12  129949.00   True  Finance
#
# [546 rows x 7 columns]

# %%
recent_emp['Mgmt'].value_counts()
# Out:
# Mgmt
# True     277
# False    269
# Name: count, dtype: int64

# %%
recent_emp['Team'].value_counts()
# Out:
# Team
# Finance    546
# Name: count, dtype: int64

# %% [markdown]
# ** How can employees earing leas than $100,000 be identify using data inversion techniques?**

# %%
data['Salary']>=100000
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4       True
#        ...
# 927     True
# 928    False
# 929    False
# 930    False
# 931     True
# Name: Salary, Length: 932, dtype: bool
