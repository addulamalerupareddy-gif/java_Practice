# %% [markdown]
# <a href="https://colab.research.google.com/github/addulamalerupareddy-gif/java_Practice/blob/main/task_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
(1)
a=(10,20,30,40,50)
print(a)
# Out:
# (10, 20, 30, 40, 50)

# %%
(2)
a=('apple','mango','orange','banana')
print(a)
# Out:
# ('apple', 'mango', 'orange', 'banana')

# %%
(3)
a=(10,20,30,40)
print(a[0])
# Out:
# 10

# %%
(4)
a=(10,20,30,40)
print(a[3])
# Out:
# 40

# %%
(5)
a=(5,10,15,20)
print(a[1])
# Out:
# 10

# %%
(6)
a=(10,20,30,40)
len(a)
# Out:
# 4

# %%
(7)
a=(10,20)
print(tuple)
# Out:
# <class 'tuple'>

# %%
(8)
a=(10,20,30,40,50)
print(a[:3])
# Out:
# (10, 20, 30)

# %%
(9)
a=(10,20,30,40,50)
print(a[3:])
# Out:
# (40, 50)

# %%
(10)
a=(10,20,30,40)
print(a[::-1])
# Out:
# (40, 30, 20, 10)

# %%
(11)
a=(1,2)
b=(3,4)
print(a+b)
# Out:
# (1, 2, 3, 4)

# %%
(12)
a=(1,2)
print(a*3)
# Out:
# (1, 2, 1, 2, 1, 2)

# %%
(13)
a=(10,45,22,80)
print(max(a))
# Out:
# 80

# %%
(14)
a=(10,45,22,80)
print(min(a))
# Out:
# 10

# %%
(15)
a=(10,20,30)
print(sum(a))
# Out:
# 60

# %%
(16)
a=(10,20,30,40)
a.index(30)
# Out:
# 2

# %%
(17)
a=(10,20,10,30,10)
a.count(10)
# Out:
# 3

# %%
(18)
a=(10,20,30)
print(list(a))
# Out:
# [10, 20, 30]

# %%
(19)
a={10,20,30,40}
print(a)
# Out:
# {40, 10, 20, 30}

# %%
(20)
a={10,20,20,30,10}
print(a)
# Out:
# {10, 20, 30}

# %%
(21)
a={10,20,30}
len(a)
# Out:
# 3

# %%
(22)
a={10,20}
print(set)
# Out:
# <class 'set'>

# %%
(23)
a={10,20,30}
a.add(40)
print(a)
# Out:
# {40, 10, 20, 30}

# %%
(24)
a={10,20}
a.update(([30,40]))
print(a)
# Out:
# {40, 10, 20, 30}

# %%
(25)
a={10,20,30}
a.remove(20)
print(a)
# Out:
# {10, 30}

# %%
(26)
a={10,20,30}
a.discard(30)
print(a)
# Out:
# {10, 20}

# %%
(27)
a={10,20,30}
a.pop()
print(a)
# Out:
# {20, 30}

# %%
(28)
a={1,2,3}
b={3,4,5}
a|b
# Out:
# {1, 2, 3, 4, 5}

# %%
(29)
a={1,2,3}
b={2,3,4}
a&b
# Out:
# {2, 3}

# %%
(30)
a={1,2,3}
b={2,3,4}
a-b
# Out:
# {1}

# %%
(31)
a={1,2,3}
b={2,3,4}
a^b
# Out:
# {1, 4}

# %%
(32)
a={10,20,30}
a.clear()
print(a)
# Out:
# set()

# %%
(33)
a={10,20,30}
a.copy()
print(a)
# Out:
# {10, 20, 30}

# %%
(34)
a={10,20,20,30}
print(a)
# Out:
# {10, 20, 30}

# %%
(35)
a={"name":"sai","age":22}
print(a)
# Out:
# {'name': 'sai', 'age': 22}

# %%
(36)
a={"name":"sai","age":22}
print(a["name"])
# Out:
# sai

# %%
(37)
a={'a':10,'b':20}
a.keys()
# Out:
# dict_keys(['a', 'b'])

# %%
(38)
a={'a':10,'b':20}
a.values()
# Out:
# dict_values([10, 20])

# %%
(39)
a={'a':10,'b':20}
a.items()
# Out:
# dict_items([('a', 10), ('b', 20)])

# %%
(40)
a={'a':10,'b':20}
a['c']=30
print(a)
# Out:
# {'a': 10, 'b': 20, 'c': 30}

# %%
(41)
a={'a':10,'b':20}
a.update({'b':50})
a
# Out:
# {'a': 10, 'b': 50}

# %%
(42)
a={'a':10,'b':20}
a.pop('b')
a
# Out:
# {'a': 10}

# %%
(43)
a={'a':10,'b':20}
a.popitem()
a
# Out:
# {'a': 10}

# %%
(44)
a={'a':10,'b':20}
a.copy()
# Out:
# {'a': 10, 'b': 20}

# %%
(45)
a=['a','b','c']
b=dict.fromkeys(a,0)
print(b)
# Out:
# {'a': 0, 'b': 0, 'c': 0}

# %%
(46)
a={'a':1}
b={'b':2}
{**a,**b}
# Out:
# {'a': 1, 'b': 2}

# %%
(47)
a={'a':10,'b':20}
a.clear()
a
# Out:
# {}

# %%
(48)
a={'a':10,'b':20,'c':30}
print(len(a))
# Out:
# 3

# %%
(49)
a={'a':10}
print(type(a))
# Out:
# <class 'dict'>

# %%
(50)
a=['a','b','c']
b=[10,20,30]
c=dict(zip(a,b))
print(c)
# Out:
# {'a': 10, 'b': 20, 'c': 30}
