# %% [markdown]
# <a href="https://colab.research.google.com/github/addulamalerupareddy-gif/java_Practice/blob/main/task_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
(1)
a=10
if a >=10:
 print('positive')
# Out:
# positive

# %%
(2)
a=-15
if a<=0:
  print('negative')
# Out:
# negative

# %%
(3)
a=24
if a>=0:
  print('even')
# Out:
# even

# %%
(4)
a=35
if a >=5:
  print('divisible by 5')
# Out:
# divisible by 5

# %%
(5)
a='python'
if a.startswith('p'):
  print('starts with p')
# Out:
# starts with p

# %%
(6)
a="program.py"
if a.endswith("py"):
 print("python file")
# Out:
# python file

# %%
(7)
a=[1,2,3,4,5,6]
if len(a)>=5:
  print('large list')
# Out:
# large list

# %%
(8)
a=(10,20,30,40)
if len(a)>=4:
  print('valid tuple')
# Out:
# valid tuple

# %%
(9)
a={10,20,30,50}
if 50 in a:
 print('found')
# Out:
# found

# %%
(10)
a={'name':'sai','age':22}
if 'name' in a:
  print('key exist')
# Out:
# key exist

# %%
(11)
a=17
if a==0:
 print('even')
else:
 print('odd')
# Out:
# odd

# %%
(12)
a=15
b=30
if a>b:
 print(a)
else:
 print(b)
# Out:
# 30

# %%
(13)
a=12
b=5
if a<b:
  print(a)
else:
  print(b)
# Out:
# 5

# %%
(14)
a="python"
b="python"
if a==b:
  print("equal")
else:
  print("not equal")
# Out:
# equal

# %%
(15)
vowel=input("a")
if vowel in "aeiouAEIOU":
  print("vowel")
else:
   print("consonant")
# Out:
# aa
# vowel

# %%
(16)
a=[]
if len(a)==0:
  print('empty list')
else:
  print('not empty')
# Out:
# empty list

# %%
(17)
a=()
if len(a)==0:
 print('empty tuple')
else:
  print('not tuple')
# Out:
# empty tuple

# %%
(18)
a={}
if len(a)==0:
  print('empty dictionary')
else:
    print('not empty')
# Out:
# empty dictionary

# %%
(19)
a=120
if a>=100:
  print('greater')
else:
   print('smaller')
# Out:
# greater

# %%
(20)
a="i love python"
if "python" in a:
  print("found")
else:
  print("not found")
# Out:
# found

# %%
(21)
a=15
b=40
c=25
if a>=b:
  print(a)
elif b>=a:
  print(b)
else:
  print(c)
# Out:
# 40

# %%
(22)
a=15
b=40
c=25
if a<=b:
  print(a)
elif b<c:
  print(b)
else:
  print(c)
# Out:
# 15

# %%
(23)
a=82
if a>=90:
  print('a')
elif b>=75:
  print('b')
elif c>=50:
  print('c')
else:
  print('fail')
# Out:
# b

# %%
(24)
a=65
if a<=12:
  print('child')
elif b<=13:
  print('teen')
elif c<=20:
  print('adult')
else:
  print('senior')
# Out:
# senior

# %%
(25)
a=27
if a>=18.5:
  print('underweight')
elif b>=24.9:
  print('normal')
elif c>=29.9:
  print('overweight')
else:
  print ('obese')
# Out:
# underweight

# %%
(26)
a=34
if a<=15:
  print('cold')
elif b<=30:
  print('pleasant')
else:
  print('hot')
# Out:
# hot

# %%
(27)
a='python12345'
if len(a)<=6:
  print('weak')
elif len(a)<=10:
  print('medium')
else:
  print('strong')
# Out:
# strong

# %%
(28)
a='@'
if a.isalpha():
  print('alphabet')
elif a.isdigit():
  print('digit')
else:
  print('special character')
# Out:
# special character

# %%
(29)
num=0
if num >0:
  print('positive')
elif num <0:
  print('negative')
else:
  print('zero')
# Out:
# zero

# %%
(30)
a=[1,2,3,4,5]
if len(a)<5:
  print('less than 5')
elif len(a)==5:
  print('exactly 5')
else:
  print('more than 5')
# Out:
# exactly 5

# %%
(31)
age=20
if age>=18:
 print('eligible to vote')
# Out:
# eligible to vote

# %%
(32)
a="admin"
b="python123"
if a=="admin":
  if b=="python123":
    print("login successful")
  else:
    print('login not successful')
else:
  print("invalid username")
# Out:
# login successful

# %%
(33)
marks=82
age=18
if marks>75:
  if age>17:
    print('admission granted')
  else:
    print('age must be above 17')
else:
    print('marks must be above 75')
# Out:
# admission granted

# %%
(34)
a=50000
b=780
if a>40000:
  if b>750:
    print('loan approved')
  else:
    print('loan not approved')
else:
  print('cibil score')
# Out:
# loan approved

# %%
(35)
a=92
b=250000
if a>85:
  if b<300000:
    print('scholarship approved')
  else:
    print('scholarship rejected')
else:
  print('income')
# Out:
# scholarship approved

# %%
(36)
a=[10,20,30,40,50,60]
if len(a)>5:
  if a[0]%2==0:
    print('first element is even')
  else:
    print('first element is odd')
else:
    print('list has 5 ')
# Out:
# first element is even

# %%
(37)
a='python'
if a.startswith('p'):
  if a.endswith('n'):
    print('starts with p and ends with n')
  else:
    print('starts with p but not ends with n')
else:
    print('doest')
# Out:
# starts with p and ends with n

# %%
(38)
a={'name':'sai','age':22}
if 'name' in a:
  if a['name']=='sai':
    print('verified')
  else:
    print('not verified')
else:
    print('keyvalue')
# Out:
# verified

# %%
(39)
a={10,20,50,100}
if 50 in a:
  if 100 in a:
    print('found')
  else:
    print('not found')
else:
    print('not found')
# Out:
# found

# %%
(40)
a=(10,20,30,40,50,120)
if len(a)>5:
  if a[-1]>100:
    print('conditon satisfied')
  else:
    print('condition not satisfied')
else:
     print('condition not satisfied')
# Out:
# conditon satisfied
