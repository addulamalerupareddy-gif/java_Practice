# %% [markdown]
# <a href="https://colab.research.google.com/github/addulamalerupareddy-gif/java_Practice/blob/main/dataloan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 10/09

# %%
import numpy as np
import pandas as pd

# %%
loan_data=pd.read_csv(r'/content/loan_data_cleaned.csv')
loan_data.head()
# Out:
#    Unnamed: 0   Loan_ID  Gender Married Dependents     Education  \
# 0           0  LP001722    Male     Yes          0      Graduate
# 1           1  LP002502  Female     Yes          2  Not Graduate
# 2           2  LP002949  Female      No         3+      Graduate
# 3           3  LP002603  Female      No          0      Graduate
# 4           4  LP001644    Male     Yes          0      Graduate
#
#   Self_Employed  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0            No            150.0             1800.0       135.0
# 1            No            210.0             2917.0        98.0
# 2            No            416.0            41667.0       350.0
# 3            No            645.0             3683.0       113.0
# 4           Yes            674.0             5296.0       168.0
#
#    Loan_Amount_Term  Credit_History Property_Area Loan_Status
# 0             360.0             1.0         Rural           N
# 1             360.0             1.0     Semiurban           Y
# ...

# %%
loan_data.head()
# Out:
#    Unnamed: 0   Loan_ID  Gender Married Dependents     Education  \
# 0           0  LP001722    Male     Yes          0      Graduate
# 1           1  LP002502  Female     Yes          2  Not Graduate
# 2           2  LP002949  Female      No         3+      Graduate
# 3           3  LP002603  Female      No          0      Graduate
# 4           4  LP001644    Male     Yes          0      Graduate
#
#   Self_Employed  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0            No            150.0             1800.0       135.0
# 1            No            210.0             2917.0        98.0
# 2            No            416.0            41667.0       350.0
# 3            No            645.0             3683.0       113.0
# 4           Yes            674.0             5296.0       168.0
#
#    Loan_Amount_Term  Credit_History Property_Area Loan_Status
# 0             360.0             1.0         Rural           N
# 1             360.0             1.0     Semiurban           Y
# ...

# %%
loan_data.tail()
# Out:
#      Unnamed: 0   Loan_ID Gender Married Dependents Education Self_Employed  \
# 606         609  LP001640   Male     Yes          0  Graduate           Yes
# 607         610  LP001536   Male     Yes         3+  Graduate            No
# 608         611  LP001585   Male     Yes         3+  Graduate            No
# 609         612  LP002101   Male     Yes          0  Graduate            No
# 610         613  LP002317   Male     Yes         3+  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 606          39147.0             4750.0       120.0             360.0
# 607          39999.0                0.0       600.0             180.0
# 608          51763.0                0.0       700.0             300.0
# 609          63337.0                0.0       490.0             180.0
# 610          81000.0                0.0       360.0             360.0
#
#      Credit_History Property_Area Loan_Status
# ...

# %%
loan_data.drop('unamed')

# %% [markdown]
# mean applicant income of male and female applicants

# %% [markdown]
# ** split**

# %%
loan_data[loan_data['Gender']=='Male']
# Out:
#      Unnamed: 0   Loan_ID Gender Married Dependents Education Self_Employed  \
# 0             0  LP001722   Male     Yes          0  Graduate            No
# 4             4  LP001644   Male     Yes          0  Graduate           Yes
# 5             5  LP001259   Male     Yes          1  Graduate           Yes
# 6             6  LP002345   Male     Yes          0  Graduate            No
# 7             7  LP002717   Male     Yes          0  Graduate            No
# ..          ...       ...    ...     ...        ...       ...           ...
# 606         609  LP001640   Male     Yes          0  Graduate           Yes
# 607         610  LP001536   Male     Yes         3+  Graduate            No
# 608         611  LP001585   Male     Yes         3+  Graduate            No
# 609         612  LP002101   Male     Yes          0  Graduate            No
# 610         613  LP002317   Male     Yes         3+  Graduate            No
#
# ...

# %%
male_app_data=loan_data[loan_data['Gender']=='Male']
male_app_data.head()
# Out:
#    Unnamed: 0   Loan_ID Gender Married Dependents Education Self_Employed  \
# 0           0  LP001722   Male     Yes          0  Graduate            No
# 4           4  LP001644   Male     Yes          0  Graduate           Yes
# 5           5  LP001259   Male     Yes          1  Graduate           Yes
# 6           6  LP002345   Male     Yes          0  Graduate            No
# 7           7  LP002717   Male     Yes          0  Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0            150.0             1800.0       135.0             360.0
# 4            674.0             5296.0       168.0             360.0
# 5           1000.0             3022.0       110.0             360.0
# 6           1025.0             2773.0       112.0             360.0
# 7           1025.0             5500.0       216.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Rural           N
# ...

# %%
female_app_data=loan_data[loan_data['Gender']=='Male']
female_app_data.head()
# Out:
#    Unnamed: 0   Loan_ID Gender Married Dependents Education Self_Employed  \
# 0           0  LP001722   Male     Yes          0  Graduate            No
# 4           4  LP001644   Male     Yes          0  Graduate           Yes
# 5           5  LP001259   Male     Yes          1  Graduate           Yes
# 6           6  LP002345   Male     Yes          0  Graduate            No
# 7           7  LP002717   Male     Yes          0  Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0            150.0             1800.0       135.0             360.0
# 4            674.0             5296.0       168.0             360.0
# 5           1000.0             3022.0       110.0             360.0
# 6           1025.0             2773.0       112.0             360.0
# 7           1025.0             5500.0       216.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Rural           N
# ...

# %% [markdown]
# apply aggregtion-mean

# %%
male_app_data['ApplicantIncome'].mean()
# Out:
# np.float64(5522.344689378758)

# %%
female_app_data['ApplicantIncome'].mean()
# Out:
# np.float64(5522.344689378758)

# %% [markdown]
# combine data into data

# %%
summ=pd.DataFrame({'mean':{'female':female_app_data['ApplicantIncome'].mean(),
                         'male':male_app_data['ApplicantIncome'].mean()}})

# %%
gb=loan_data.groupby('Gender') #group splits loan_data into parts based on gender
gb

# %%
gb_list=list(gb)
gb_list
# Out:
# [('Female',
#        Unnamed: 0   Loan_ID  Gender Married Dependents     Education  \
#   1             1  LP002502  Female     Yes          2  Not Graduate
#   2             2  LP002949  Female      No         3+      Graduate
#   3             3  LP002603  Female      No          0      Graduate
#   9             9  LP001267  Female     Yes          2      Graduate
#   10           11  LP002287  Female      No          0      Graduate
#   ..          ...       ...     ...     ...        ...           ...
#   584         585  LP001516  Female     Yes          2      Graduate
#   588         589  LP002194  Female      No          0      Graduate
#   595         596  LP002582  Female      No          0  Not Graduate
#   597         598  LP002731  Female      No          0  Not Graduate
#   599         600  LP002813  Female     Yes          1      Graduate
#
#       Self_Employed  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# ...

# %%
gb_list[0]
# Out:
# ('Female',
#       Unnamed: 0   Loan_ID  Gender Married Dependents     Education  \
#  1             1  LP002502  Female     Yes          2  Not Graduate
#  2             2  LP002949  Female      No         3+      Graduate
#  3             3  LP002603  Female      No          0      Graduate
#  9             9  LP001267  Female     Yes          2      Graduate
#  10           11  LP002287  Female      No          0      Graduate
#  ..          ...       ...     ...     ...        ...           ...
#  584         585  LP001516  Female     Yes          2      Graduate
#  588         589  LP002194  Female      No          0      Graduate
#  595         596  LP002582  Female      No          0  Not Graduate
#  597         598  LP002731  Female      No          0  Not Graduate
#  599         600  LP002813  Female     Yes          1      Graduate
#
#      Self_Employed  ApplicantIncome  CoapplicantIncome  LoanAmount  \
#  1              No            210.0             2917.0        98.0
# ...

# %%
gb_list[1]
# Out:
# ('Male',
#       Unnamed: 0   Loan_ID Gender Married Dependents Education Self_Employed  \
#  0             0  LP001722   Male     Yes          0  Graduate            No
#  4             4  LP001644   Male     Yes          0  Graduate           Yes
#  5             5  LP001259   Male     Yes          1  Graduate           Yes
#  6             6  LP002345   Male     Yes          0  Graduate            No
#  7             7  LP002717   Male     Yes          0  Graduate            No
#  ..          ...       ...    ...     ...        ...       ...           ...
#  606         609  LP001640   Male     Yes          0  Graduate           Yes
#  607         610  LP001536   Male     Yes         3+  Graduate            No
#  608         611  LP001585   Male     Yes         3+  Graduate            No
#  609         612  LP002101   Male     Yes          0  Graduate            No
#  610         613  LP002317   Male     Yes         3+  Graduate            No
#
# ...

# %%
gb_list[0][0]
# Out:
# 'Female'

# %%
gb_list[1][0]
# Out:
# 'Male'

# %%
gb_list[1][1].head()
# Out:
#    Unnamed: 0   Loan_ID Gender Married Dependents Education Self_Employed  \
# 0           0  LP001722   Male     Yes          0  Graduate            No
# 4           4  LP001644   Male     Yes          0  Graduate           Yes
# 5           5  LP001259   Male     Yes          1  Graduate           Yes
# 6           6  LP002345   Male     Yes          0  Graduate            No
# 7           7  LP002717   Male     Yes          0  Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0            150.0             1800.0       135.0             360.0
# 4            674.0             5296.0       168.0             360.0
# 5           1000.0             3022.0       110.0             360.0
# 6           1025.0             2773.0       112.0             360.0
# 7           1025.0             5500.0       216.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Rural           N
# ...

# %%
gb=loan_data.groupby('Gender')['ApplicantIncome']
gb

# %%
gb_list=list(gb)
gb_list
# Out:
# [('Female',
#   1        210.0
#   2        416.0
#   3        645.0
#   9       1378.0
#   10      1500.0
#           ...
#   584    14866.0
#   588    15759.0
#   595    17263.0
#   597    18165.0
#   599    19484.0
#   Name: ApplicantIncome, Length: 112, dtype: float64),
#  ('Male',
#   0        150.0
#   4        674.0
#   5       1000.0
#   6       1025.0
#   7       1025.0
#           ...
#   606    39147.0
#   607    39999.0
#   608    51763.0
#   609    63337.0
#   610    81000.0
#   Name: ApplicantIncome, Length: 499, dtype: float64)]

# %%
loan_data.groupby('Gender')['ApplicantIncome'].mean()
# Out:
# Gender
# Female    4643.473214
# Male      5522.344689
# Name: ApplicantIncome, dtype: float64

# %% [markdown]
# ** mean applicant incomes of married and gender categories**
#
# -mean applicant income of male and married.
#
# -mean applicant income of male and unmarried.
#
# -mean applicant income of female and married.
#
# --mean applicant income of female and umarried

# %%
loan_data.groupby(['Gender','Married'])['ApplicantIncome'].agg('mean')
# Out:
# Gender  Married
# Female  No         4503.787500
#         Yes        4992.687500
# Male    No         5279.901515
#         Yes        5609.544959
# Name: ApplicantIncome, dtype: float64

# %%
list(loan_data.groupby(['Gender','Married']))
# Out:
# [(('Female', 'No'),
#        Unnamed: 0   Loan_ID  Gender Married Dependents     Education  \
#   2             2  LP002949  Female      No         3+      Graduate
#   3             3  LP002603  Female      No          0      Graduate
#   10           11  LP002287  Female      No          0      Graduate
#   20           21  LP001917  Female      No          0      Graduate
#   24           25  LP002113  Female      No         3+  Not Graduate
#   ..          ...       ...     ...     ...        ...           ...
#   563         564  LP001422  Female      No          0      Graduate
#   579         580  LP002634  Female      No          1      Graduate
#   588         589  LP002194  Female      No          0      Graduate
#   595         596  LP002582  Female      No          0  Not Graduate
#   597         598  LP002731  Female      No          0  Not Graduate
#
#       Self_Employed  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# ...

# %%
loan_data.pivot_table(index='Gender',
                      values='ApplicantIncome',
                      aggfunc='mean')
# Out:
#         ApplicantIncome
# Gender
# Female      4643.473214
# Male        5522.344689

# %%
summ=loan_data.pivot_table(index='Gender',
                      values='ApplicantIncome',
                      aggfunc='mean')
summ
# Out:
#         ApplicantIncome
# Gender
# Female      4643.473214
# Male        5522.344689

# %%
summ.plot(kind='bar',figsize=(4,3))
# Out:
# <Axes: xlabel='Gender'>

# %%
summ=loan_data.pivot_table(columns='Gender',
                      values='ApplicantIncome',
                      aggfunc='mean')
summ
# Out:
# Gender                Female         Male
# ApplicantIncome  4643.473214  5522.344689

# %%
summ.plot(kind='bar',figsize=(4,3))
# Out:
# <Axes: >

# %%
summ=loan_data.pivot_table(index='Gender',
                           columns='Married',
                      values='ApplicantIncome',
                      aggfunc='mean')
summ
# Out:
# Married           No          Yes
# Gender
# Female   4503.787500  4992.687500
# Male     5279.901515  5609.544959

# %%
summ.plot(kind='bar',figsize=(4,3))
# Out:
# <Axes: xlabel='Gender'>

# %%
summ=pd.crosstab(columns=loan_data['Gender'],
                  index=loan_data['Married'] ,
                  values=loan_data['ApplicantIncome'],
                  aggfunc='mean')
summ
# Out:
# Gender      Female         Male
# Married
# No       4503.7875  5279.901515
# Yes      4992.6875  5609.544959

# %%
summ=loan_data.pivot_table(index='Gender',
                           values='ApplicantIncome',
                           aggfunc='mean')
summ
# Out:
#         ApplicantIncome
# Gender
# Female      4643.473214
# Male        5522.344689

# %%
summ.plot(kind='bar',figsize=(4,3))
# Out:
# <Axes: xlabel='Gender'>

# %%
summ=loan_data.pivot_table(index='Gender',
                           values=['ApplicantIncome','CoapplicantIncome','LoanAmount'],
                           aggfunc='mean')
summ
# Out:
#         ApplicantIncome  CoapplicantIncome  LoanAmount
# Gender
# Female      4643.473214        1108.008929  126.732143
# Male        5522.344689        1722.274389  148.723447

# %%
summ.plot(kind='bar',figsize=(4,3))
# Out:
# <Axes: xlabel='Gender'>
