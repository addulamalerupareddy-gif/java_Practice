# %% [markdown]
# <a href="https://colab.research.google.com/github/addulamalerupareddy-gif/java_Practice/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=int(input('enter a number'))
if n % 2 == 0:
  print('even')
else:
  print('odd')
# Out:
# enter a number:4
# even

# %%
a=10
b=20
if a>b:
  print(a)
else:
  print(b)
# Out:
# 20

# %%
a=10
b=15
c=20
if a>b in a>c:
  print(a)
elif b>c:
  print(b)
else:
  print(c)
# Out:
# 20

# %%
n=10
total=0
for i in range(1,n+1):
  total+=1
print(total)
# Out:
# 10

# %%
a=5
fact=1
for i in range(1,a+1):
  fact*=i
print(fact)
# Out:
# 120

# %%
a=1234
reverse=0
while a>0:
  digit = n%10
  reverse=reverse*10+digit
  n//=10
print(reverse)

# %%
a=1234
print(a.reverse())
