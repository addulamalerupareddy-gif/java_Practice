# %% [markdown]
# <a href="https://colab.research.google.com/github/addulamalerupareddy-gif/java_Practice/blob/main/taskkk.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
(1)
a=[10,20,30,40,50]
print(a)
# Out:
# [10, 20, 30, 40, 50]

# %%
(2)
fruits=['apple','mango','orange','banana','grapes']
print(fruits)
# Out:
# ['apple', 'mango', 'orange', 'banana', 'grapes']

# %%
(3)
a=[10,20,30,40]
print(a[0])
# Out:
# 10

# %%
(4)
a=[10,20,30,40]
print(a[3])
# Out:
# 40

# %%
(5)
a=[10,20,30,40]
print(len(a))
# Out:
# 4

# %%
(6)
a=[10,20,30,40]
print(type(a))
# Out:
# <class 'list'>

# %%
(7)
a=[10,20,30,40]
a[1]=100
print(a)
# Out:
# [10, 100, 30, 40]

# %%
(8)
a=[10,20,30,40]
a[3]=500
print(a)
# Out:
# [10, 20, 30, 500]

# %%
(9)
a=[1,2]
b=[3,4]
c=a+b
print(c)
# Out:
# [1, 2, 3, 4]

# %%
(10)
a=[1,2]
b=a*3
print(b)
# Out:
# [1, 2, 1, 2, 1, 2]

# %% [markdown]
# list indexing

# %%
(11)
a=[5,10,15]
print(a[0])
# Out:
# 5

# %%
(12)
a=[5,10,15,20]
print(a[2])
# Out:
# 15

# %%
(13)
a=[5,10,15,20]
print(a[-1])
# Out:
# 20

# %%
(14)
a=[5,10,15,20]
print(a[-2])
# Out:
# 15

# %%
(15)
a=[10,20,30,40]
print(a[0], a[-1])
# Out:
# 10 40

# %%
(16)
a=[10,20,30,40,50]
print(a[2])
# Out:
# 30

# %%
(17)
a=[10,20,30,40,50,60]
print(a[4])
# Out:
# 50

# %%
(18)
a=[10,20,30,40]
print(a[2])
# Out:
# 30

# %% [markdown]
# list slicing

# %%
(19)
a=[10,20,30,40,50]
print(a[:3])
# Out:
# [10, 20, 30]

# %%
(20)
a=[10,20,30,40,50]
print(a[3:])
# Out:
# [40, 50]

# %%
(21)
a=[10,20,30,40,50]
print(a[1:4])
# Out:
# [20, 30, 40]

# %%
(22)
a=[10,20,30,40,50,60]
print(a[::2])
# Out:
# [10, 30, 50]

# %%
(23)
a=[10,20,30,40]
print(a[::-1])
# Out:
# [40, 30, 20, 10]

# %%
(24)
a=[10,20,30,40]
print(a[1::1])
# Out:
# [20, 30, 40]

# %%
(25)
a=[10,20,30,40]
print(a[:3:1])
# Out:
# [10, 20, 30]

# %%
(26)
a=[10,20,30,40,50]
print(a[2::1])
# Out:
# [30, 40, 50]

# %% [markdown]
# List Methods

# %%
(27)
a=[10,20,30]
a.append(40)
print(a)
# Out:
# [10, 20, 30, 40]

# %%
(28)
a=[10,20,40]
a.insert(2,30)
print(a)
# Out:
# [10, 20, 30, 40]

# %%
(29)
a=[10,20,30,40]
a.remove(30)
print(a)
# Out:
# [10, 20, 40]

# %%
(30)
a=[10,20,30,40]
a.pop(3)
print(a)
# Out:
# [10, 20, 30]

# %%
(31)
a=[10,20,30]
a.clear()
print(a)
# Out:
# []

# %%
(32)
a=[10,20,30]
a.copy()
print(a)
# Out:
# [10, 20, 30]

# %%
(33)
a=[10,20]
b=[30,40]
a.extend(b)
print(a)
# Out:
# [10, 20, 30, 40]

# %%
(34)
a=[30,10,20]
a.sort()
print(a)
# Out:
# [10, 20, 30]

# %%
(35)
a=[10,20,30]
a.reverse()
print(a)
# Out:
# [30, 20, 10]

# %%
(36)
a=[10,20,10,30,10]
b=10
count=a.count(10)
print(count)
# Out:
# 3

# %%
(37)
a=[10,20,30,40]
b=30
index=a.index(30)
print(index)
# Out:
# 2

# %%
(38)
a=[10,40,10,60]
print("max:",max(a))
print("min:",min(a))
# Out:
# max: 60
# min: 10

# %% [markdown]
# Nested Lists & Mixed

# %%
(39)
a=[[10,20],[30,40]]
print(a)
# Out:
# [[10, 20], [30, 40]]

# %%
(40)
a=[[10,20],[30,40]]
print(a[1][0])
# Out:
# 30

# %%
(41)
a=[[10,20],[30,40]]
print(a[0][1])
# Out:
# 20

# %%
(42)
a=[1]
b=[2]
c=[3]
list=a+b+c
print(list)
# Out:
# [1, 2, 3]

# %%
(43)
a=[10,2.5,'python',True]
print(a)
# Out:
# [10, 2.5, 'python', True]

# %%
(44)
a=[10,20,30,40,50]
a[:3]=[100,200,300]
print(a)
# Out:
# [100, 200, 300, 40, 50]

# %%
(45)
a=[10,20,30,40,50]
del a[1:4]
print(a)
# Out:
# [10, 50]
