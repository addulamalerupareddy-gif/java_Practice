# %% [markdown]
# <a href="https://colab.research.google.com/github/addulamalerupareddy-gif/java_Practice/blob/main/task06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def fun1():
  print('welcome to python funtion')
fun1()
# Out:
# welcome to python funtion

# %%
def course_info():
  print('course:data')
  print('module:python')
course_info()
# Out:
# course:data
# module:python

# %%
def developer():
  print("name:rahul")
  print("city:hyderabad")
developer()
# Out:
# name:rahul
# city:hyderabad

# %%
(4)
def display(name):
  print("hello",name)
display('rahul')
# Out:
# hello rahul

# %%
(5)
def square(a):
  print(a*a)
square(5)
# Out:
# 25

# %%
(6)
def cube(a):
  print(a*a*a)
cube(4)
# Out:
# 64

# %%
(7)
def add(a,b):
  print(a+b)
add(10,20)
# Out:
# 30

# %%
(8)
def sub(a,b):
  print(a-b)
sub(30,10)
# Out:
# 20

# %%
(9)
def mul():
  print(6*7)
mul()
# Out:
# 42

# %%
(10)
def div():
  print(20/5)
div()
# Out:
# 4.0

# %%
(11)
def name_course(name,course):
  print('student name:',name)
  print('course:',course)
name_course('rahul','python')
# Out:
# student name: rahul
# course: python

# %%
(12)
def employee(name,department):
  print('Employee Name:',name)
  print('Department:',department)
employee('Ravi','Hr')
# Out:
# Employee Name: Ravi
# Department: Hr

# %%
(13)
def book(title,author):
  print('Book title:',title)
  print('Author:',author)
book('python Basics','john')
# Out:
# Book title: python Basics
# Author: john

# %%
(14)
def student(name,course):
  print('student name:',name)
  print('course:',course)
student(name='rahul',course='python')
# Out:
# student name: rahul
# course: python

# %%
(15)
def student(name,course):
 print('student name:',name)
 print('course:',course)
student(course='python',name='rahul')
# Out:
# student name: rahul
# course: python

# %%
(16)
def employee(name,age,city):
  print('name:',name)
  print('age:',age)
  print('city:',city)
employee('anil','25','hyderabad')
# Out:
# name: anil
# age: 25
# city: hyderabad

# %%
(17)
def employee(name,age,city):
  print('name:',name)
  print('age:',age)
  print('city:',city)
employee(name='anil',city='hyderabad',age='25')
# Out:
# name: anil
# age: 25
# city: hyderabad

# %%
(18)
def calculator(num1,num2):
  print('add:',num1+num2)
  print('sub:',num1-num2)
  print('mul:',num1*num2)
  print('div:',num1/num2)
calculator(15,5)
# Out:
# add: 20
# sub: 10
# mul: 75
# div: 3.0

# %%
(19)
def add_numbers(num1,num2):
  print(num1+num2)
print('using print():')
add_numbers(10,20)
# Out:
# using print():
# 30

# %%
(19)
def add_numbers(num1,num2):
  return num1+num2
print('using return():')
add_numbers(10,20)
# Out:
# using return():
# 30

# %%
(20)
def student_profile(name,age,course,city):
  print('name:',name)
  print('age:',age)
  print('course:',course)
  print('city:',city)
student_profile(name='rahul',age='25',course='python',city='hyderabad')
# Out:
# name: rahul
# age: 25
# course: python
# city: hyderabad
