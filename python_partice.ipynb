# %% [markdown]
# <a href="https://colab.research.google.com/github/addulamalerupareddy-gif/java_Practice/blob/main/python_partice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 20/07/26

# %%
#built in
t=(1,2,3,4,1)
t.count(1) #counts repitation
# Out:
# 2

# %%
t=(1,2,3,4,1)
t.index(2) #gives the index position of the value
# Out:
# 1

# %%
t=(1,2,3,4,1)
len(t) #length of the tuple
# Out:
# 5

# %%
t=(1,2,3,4,1)
min(t)
# Out:
# 1

# %%
t=(1,2,3,4,1)
max(t)
# Out:
# 4

# %%
t=(1,2,3,4,1)
sum(t) #total
# Out:
# 11

# %%
t=[1,2,3,4,1]
del t [1:3] #wipes out the value and the variable
t
# Out:
# [1, 4, 1]

# %%
#type casting
a=3
a=float(a)
a
# Out:
# 3.0

# %%
a=7+8j
str(a)
# Out:
# '(7+8j)'

# %%
a='manisha'
bool(a)
# Out:
# True

# %%
a=1,2,3
a,b,c=8,9,7
type(a)
b=9
type(b)
# Out:
# int

# %%
#set
a={1}
type(a)
a=[]
a=set(a)
#order,heterogeneous,mutability,nested,duplication

# %%
a={10,20,30,40,}
a
# Out:
# {10, 20, 30, 40}

# %%
a={10,"Rupa",1.5,True,(1,2)} #cannat access unhashable
a
# Out:
# {(1, 2), 1.5, 10, 'Rupa', True}

# %%
a={1,2,3}
a.add(4)
a
a.remove(2)
a
# Out:
# {1, 3, 4}

# %%
#string is immutable-->hashable
a='manisha'
print(id(a))
b=a.replace('m','kl')
print(id(b))
# Out:
# 140313102780480
# 140313100802096

# %%
#list is mutable-->unhashable
a=[9,8,7]
print(id(a))
a[0]='kl'
print(id(a))
# Out:
# 140313100806528
# 140313100806528

# %%
#set
a={1,2,3}
b={3,4,5}
a.union(b) #all elements
a|b
# Out:
# {1, 2, 3, 4, 5}

# %%
a={1,2,3}
b={3,4,5}
a.intersection(b) #common elements
a&b
# Out:
# {3}

# %%
a={1,2,3}
b={3,4,5}
a.difference(b) #all elements of the excluding the common elements with b
a-b
# Out:
# {1, 2}

# %%
a={1,2,3}
b={3,4,5}
a.symmetric_difference(b) #all elements of a and b expect the common element
(a|b)-(a&b)
# Out:
# {1, 2, 4, 5}

# %%
a={1,2,3,90,'kl'}
a.add(4) #adds one element at a time
a
# Out:
# {1, 2, 3, 4, 90, 'kl'}

# %%
a={1,2,3,90,'kl'}
a.update('ghi') #adds multiable elements at a time
a
# Out:
# {1, 2, 3, 90, 'g', 'h', 'i', 'kl'}

# %%
a={1,2,3,90,'kl'}
a.update()
a
# Out:
# {1, 2, 3, 90, 'kl'}

# %%
a={1,2,3,90,'kl'}
a.pop()
a
# Out:
# {2, 3, 90, 'kl'}

# %%
a={1,2,3,90,'kl'}
a.clear()

# %%
a={1,2,3,90,'kl'}
a.discard(2)
a
# Out:
# {1, 3, 90, 'kl'}

# %%
a={1}
type(a)
# Out:
# set

# %%
a=[1,2]
a.insert(10,5)
print(a)
# Out:
# [1, 2, 5]

# %% [markdown]
# 21/07/26

# %%
# dictionary:works on key value pair
keys are expected to be unique

# %%
x={1:2,3:4,5:6}
x.keys()
# Out:
# dict_keys([1, 3, 5])

# %%
x={1:2,3:4,5:6}
x.keys()
val=x.values()
type(val)
# Out:
# dict_values

# %%
x={1:2,3:4,5:6}
val=list(val)
type(val)
# Out:
# list

# %%
x={1:2,3:4,5:6}
x.values()
type(val)
# Out:
# list

# %%
#order
x={1:2,3:4,5:6}
type(x)
x
# Out:
# {1: 2, 3: 4, 5: 6}

# %%
x={1:2,3:4,5:6} #homogeneous/hetrogeneous
x
#keys should be of type hashable
# Out:
# {1: 2, 3: 4, 5: 6}

# %%
#duplication
a={'1':2,'1':4,5:6}
a
#duplication is not allowed at keys position
#incase of duplication,the latest value is preserved
#duplication is allowed at values positon
# Out:
# {'1': 4, 5: 6}

# %%
#mutability
a={1:[9,2],3:4,9:8}
a[1]=[7,88,12]
#values are mutable,ther by unhashable
#while keys are immutable,ther by hashsable

# %%
a={{8:9}:[9:2],3:4,9:8}
#dictionary is unhasable
# Out:
#   File "/tmp/ipykernel_1522/4182809531.py", line 1
#     a={{8:9}:[9:2],3:4,9:8}
#                ^
# SyntaxError: invalid syntax

# %%
a={1:2,3:4,6:7}
b={11:22,33:44,66:77}
{**a,**b}
# Out:
# {1: 2, 3: 4, 6: 7, 11: 22, 33: 44, 66: 77}

# %%
a={1:2,3:4,6:7}
a.keys()
# Out:
# dict_keys([1, 3, 6])

# %%
a={1:2,3:4,6:7}
a.values()
# Out:
# dict_values([2, 4, 7])

# %%
a={1:2,3:4,6:7}
a.items()
# Out:
# dict_items([(1, 2), (3, 4), (6, 7)])

# %%
a={1:2,3:4,6:7}
a.pop(1)
# Out:
# 2

# %%
a={1:2,3:4,6:7}
a.popitem()
# Out:
# (6, 7)

# %%
a={1:2,3:4,6:7}

# %%
del()

# %%
a.get(1) #key based
# Out:
# 2

# %%
a={1:2,3:4,6:7}
a.update({23:'dhk'})
a
# Out:
# {1: 2, 3: 4, 6: 7, 23: 'dhk'}

# %%
a={1:2,3:4,6:7}

# %%
a.fromkeys(a,b)
# Out:
# {1: {11: 22, 33: 44, 66: 77},
#  3: {11: 22, 33: 44, 66: 77},
#  6: {11: 22, 33: 44, 66: 77},
#  23: {11: 22, 33: 44, 66: 77}}

# %%
zip(a,b)

# %%
a={1:2,3:4,6:7}
list(zip(a,b))
# Out:
# [(1, 11), (3, 33), (6, 66)]

# %%
dict(zip(a,b))
# Out:
# {1: 11, 3: 33, 6: 66}

# %%
a.get(6)
# Out:
# 7

# %%
print('guess the word')
my_word='rupa'

# %% [markdown]
# 22/07/26

# %%
print('guess the word')
my_word='mahesh'
word=input('give your word')
print(word)
# Out:
# guess the word
# give your wordrupa
# rupa

# %%
#condition statement
a=16
if a==11:
  print('yes')
  print('body of if')
print('thank you')
# Out:
# thank you

# %%
#get the marks of a student and inform them only they are passed
a=50
if a==40:
  print('good')
  print('nice')
print('thank you')
# Out:
# thank you

# %%
a=10
b=30
if a==10 and b==30:
  print('match found')
  print('thank you')
# Out:
# match found
# thank you

# %%
a=100
b=30
if a==10 or b==30:
  print('match found')
print('thank you')
# Out:
# match found
# thank you

# %%
#multiple if
a=100
b=300
if a==100:
  print('a found')
if b==300:
  print('b found')
print('thank you')
# Out:
# a found
# b found
# thank you

# %%
a=10
b=20
if a==10:
  if b==20:
    print('yes')
    print('yes1')
print('thank you')
# Out:
# yes
# yes1
# thank you

# %%
a=10
b=20
if a==10:
  if b==200:
    print('yes')
  print('yes1')
print('thank you')
# Out:
# yes1
# thank you

# %%
name=input('name')
age=int(input('age'))
if 'a'in name or 'e'in name or 'i'in name or 'o'in name or 'u'in name:
  print('vowel found')
if age>20:
  print('welcome club')
# Out:
# namerupa
# age21
# vowel found
# welcome club

# %%
name=input('name')
age=int(input('age'))
if 'a'in name or 'e'in name or 'i'in name or 'o'in name or 'u'in name:
  print('vowel found')
if age>20:
  print('welcome club')
# Out:
# namerupa
# age19
# vowel found

# %%
a=10
if a==20:
  print('this is a')
else:
  print('this is not a')
# Out:
# this is not a

# %%
marks=int(input('enter your marks'))
if marks>=0 and marks<=100:
  if marks>=80:
   print('pass')
  else:
   print('fail')
else:
   print('give correct marks')
# Out:
# enter your marks80
# pass

# %% [markdown]
# 23/07/26

# %%
age=int(input('enter your age'))
if age>=20:
 dob=input('enter your dob')
 print(dob)
 dob=dob.split('/')
 dob_=int(dob[0])+int(dob[1])+int(dob[2])
 print(dob_)
 if len(str(dob_))>1:
  dob_=str(dob_)
  dob_=int(dob_[0])+int(dob_[1])+int(dob_[2])+int(dob_[3])
 print(dob_)
 if len(str(dob_))>1:
  dob_=str(dob_)
  dob_=int(dob_[0])+int(dob_[1])
 print(dob_)
# Out:
# enter your age21
# enter your dob29/09/2003
# 29/09/2003
# 2041
# 7
# 7

# %%
a=35
if a>=10 and a<=19:
  print('this is group a')
elif a>=20 and a<29:
  print('this is group b')
elif a>=30:
  print('this is group c')
# Out:
# this is group c

# %%
a=9
if a%2==0:
 print('even')
else:
  print('odd')
# Out:
# odd

# %%
marks=int(input('enter marks'))
if marks>=70:
  print('grade a')
elif marks>=60:
  print('grade b')
elif marks>=50:
  print('grade c')
else:
  print('fail')
# Out:
# enter marks77
# grade a

# %%
i=1 #initilalization
while i<=5:
  print(i)
  i+=1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
i
# Out:
# 6

# %%
i=5
while i>=1:
  print(i)
  i-=1
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
i
# Out:
# 0

# %% [markdown]
# 24/07/26

# %%
a=[14,24,36,48]
i=0
while i<len(a):
  print(a[i])
  i+=1
# Out:
# 14
# 24
# 36
# 48

# %%
a=[14,24,36,48]
i=0
while i<len(a):
  print(a[i],end='')
  print(a[i],end='/n')
  print()
  i+=1
# Out:
# 1414/n
# 2424/n
# 3636/n
# 4848/n

# %%
a=[14,24,36,48]
i=0
while i<len(a):
  print(a[i],end='*')
  print()
  i+=1
# Out:
# 14*
# 24*
# 36*
# 48*

# %%
a=[14,24,36,48]
i=0
while i<len(a):
  print(a[i],'k',sep='&',end='*')
  print()
  i+=1
# Out:
# 14&k*
# 24&k*
# 36&k*
# 48&k*

# %%
i=0
while i<=5:
  print('*'*i)
  i+=1
# Out:
# *
# **
# ***
# ****
# *****

# %%
i=5
while i>=1:
  print('*'*i)
  i-=1
# Out:
# *****
# ****
# ***
# **
# *

# %%
i=1
while i<=5:
  print('*'*i,'*'*i,sep=' '*(10-2*i))
  i+=1
# Out:
# *        *
# **      **
# ***    ***
# ****  ****
# **********

# %%
num=10
i=1
fact=0
while i<=num:
  if num%i==0:
   fact+=1
  i+=1
if fact==2:
    print(num,'is prime')
else:
    print(num,'is composite')
# Out:
# 10 is composite

# %%
 a=[45,7,66,12,13,1]
index=0
while index<len(a):
  fact
fact=0
while i<=num:
  if num%i==0:
   fact+=1
  i+=1
if fact==2:
    print(num,'is prime')
else:
    print(num,'is composite')
