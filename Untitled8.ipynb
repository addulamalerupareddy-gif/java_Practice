# %% [markdown]
# <a href="https://colab.research.google.com/github/addulamalerupareddy-gif/java_Practice/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 02/09

# %%
import pandas as pd
import numpy as np

# %%
import numpy as np
import pandas as pd
df=pd.DataFrame(np.arange(1,31).reshape(5,6),
                index=['r1','r2','r3','r4','r5'],
                columns=['c1','c2','c3','c4','c5','c6'])
df
# Out:
#     c1  c2  c3  c4  c5  c6
# r1   1   2   3   4   5   6
# r2   7   8   9  10  11  12
# r3  13  14  15  16  17  18
# r4  19  20  21  22  23  24
# r5  25  26  27  28  29  30

# %% [markdown]
# filter the column,based  on row r3 with values greathan 15

# %%
df.loc[:,df.loc['r3']>15] #with columns bools filter
# Out:
#     c4  c5  c6
# r1   4   5   6
# r2  10  11  12
# r3  16  17  18
# r4  22  23  24
# r5  28  29  30

# %%
df.loc[:,df.loc['r2']%2==0]
# Out:
#     c2  c4  c6
# r1   2   4   6
# r2   8  10  12
# r3  14  16  18
# r4  20  22  24
# r5  26  28  30

# %%
df.loc['r2']%2==0
# Out:
# c1    False
# c2     True
# c3    False
# c4     True
# c5    False
# c6     True
# Name: r2, dtype: bool

# %% [markdown]
# get the column where r2 >10 and r3>15

# %%
df.columns[(df.loc['r2']>10) &(df.loc['r3']<15)]
# Out:
# Index([], dtype='object')

# %%
df.loc['r1']>10
# Out:
# c1    False
# c2    False
# c3    False
# c4    False
# c5    False
# c6    False
# Name: r1, dtype: bool

# %%
df.loc['r3']<15
# Out:
# c1     True
# c2     True
# c3    False
# c4    False
# c5    False
# c6    False
# Name: r3, dtype: bool

# %%
df.columns[(df.loc['r2']>10)|(df.loc['r3']<15)]
# Out:
# Index(['c1', 'c2', 'c5', 'c6'], dtype='object')

# %% [markdown]
# Get rows values in c3 >10

# %%
df.loc[(df.loc[:,'c3']>10)]
# Out:
#     c1  c2  c3  c4  c5  c6
# r3  13  14  15  16  17  18
# r4  19  20  21  22  23  24
# r5  25  26  27  28  29  30

# %%
df.loc[:,'c3']>10
# Out:
# r1    False
# r2    False
# r3     True
# r4     True
# r5     True
# Name: c3, dtype: bool

# %% [markdown]
# c2+c4

# %%
df.loc[(df.loc[:,'c3']>10),['c2','c4']]
# Out:
#     c2  c4
# r3  14  16
# r4  20  22
# r5  26  28

# %% [markdown]
# traditional-.loc

# %%
df.loc[:,'c3']>10
# Out:
# r1    False
# r2    False
# r3     True
# r4     True
# r5     True
# Name: c3, dtype: bool

# %%
df.loc[(df.loc[:,'c3']>10),['c2','c4']]
# Out:
#     c2  c4
# r3  14  16
# r4  20  22
# r5  26  28

# %%
df.loc[df.loc[:,'c3']>10,'c2':'c4':2]
# Out:
#     c2  c4
# r3  14  16
# r4  20  22
# r5  26  28

# %% [markdown]
# easy

# %%
df.c3
# Out:
# r1     3
# r2     9
# r3    15
# r4    21
# r5    27
# Name: c3, dtype: int64

# %%
df['c3']>10
# Out:
# r1    False
# r2    False
# r3     True
# r4     True
# r5     True
# Name: c3, dtype: bool

# %%
df[df['c3']>10]
# Out:
#     c1  c2  c3  c4  c5  c6
# r3  13  14  15  16  17  18
# r4  19  20  21  22  23  24
# r5  25  26  27  28  29  30

# %% [markdown]
# cannot get the subset of columns

# %%
df[df['c3']>10][['c2','c4']] #not-recommended-erroes
# Out:
#     c2  c4
# r3  14  16
# r4  20  22
# r5  26  28

# %%
df.loc[(df.loc[:,'c1']<8) | (df.loc[:,'c5']>15)]
# Out:
#     c1  c2  c3  c4  c5  c6
# r1   1   2   3   4   5   6
# r2   7   8   9  10  11  12
# r3  13  14  15  16  17  18
# r4  19  20  21  22  23  24
# r5  25  26  27  28  29  30

# %%
df.loc[(df.loc[:,'c1']<8) | (df.loc[:,'c5']>15)][['c1','c5']]
# Out:
#     c1  c5
# r1   1   5
# r2   7  11
# r3  13  17
# r4  19  23
# r5  25  29

# %%
df.loc[(df.loc[:,'c1']<8) | (df.loc[:,'c5']>15),'c1':'c5':4]
# Out:
#     c1  c5
# r1   1   5
# r2   7  11
# r3  13  17
# r4  19  23
# r5  25  29

# %%
df['c1']<8
# Out:
# r1     True
# r2     True
# r3    False
# r4    False
# r5    False
# Name: c1, dtype: bool

# %%
df['c5']>15
# Out:
# r1    False
# r2    False
# r3     True
# r4     True
# r5     True
# Name: c5, dtype: bool

# %%
(df['c1']<8) | (df['c5']>15)
# Out:
# r1    True
# r2    True
# r3    True
# r4    True
# r5    True
# dtype: bool

# %%
pd.read_csv(r'/content/iris_dirty.csv')
# Out:
#      Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  \
# 0             1           5.1          3.5           1.4          0.2
# 1             2           4.9          3.0           1.4          0.2
# 2             3           4.7          3.2           1.3          0.2
# 3             4           4.6          3.1           1.5          0.2
# 4             5           NaN          3.6           1.4          0.2
# ..          ...           ...          ...           ...          ...
# 145         146           6.7          3.0           5.2          2.3
# 146         147           6.3          2.5           5.0          1.9
# 147         148           6.5          3.0           5.2          2.0
# 148         149           6.2          3.4           5.4          2.3
# 149         150           NaN          3.0           5.1          1.8
#
#        Species
# 0       Setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# ...

# %%
data=pd.read_csv(r'/content/iris_dirty.csv')
data
# Out:
#      Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  \
# 0             1           5.1          3.5           1.4          0.2
# 1             2           4.9          3.0           1.4          0.2
# 2             3           4.7          3.2           1.3          0.2
# 3             4           4.6          3.1           1.5          0.2
# 4             5           NaN          3.6           1.4          0.2
# ..          ...           ...          ...           ...          ...
# 145         146           6.7          3.0           5.2          2.3
# 146         147           6.3          2.5           5.0          1.9
# 147         148           6.5          3.0           5.2          2.0
# 148         149           6.2          3.4           5.4          2.3
# 149         150           NaN          3.0           5.1          1.8
#
#        Species
# 0       Setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# ...

# %%
data=pd.read_csv(r'/content/iris_dirty.csv', header=None)
data
# Out:
#          0             1            2             3            4          5
# 0      NaN  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 1      1.0           5.1          3.5           1.4          0.2     Setosa
# 2      2.0           4.9            3           1.4          0.2     setosa
# 3      3.0           4.7          3.2           1.3          0.2     setosa
# 4      4.0           4.6          3.1           1.5          0.2     setosa
# ..     ...           ...          ...           ...          ...        ...
# 146  146.0           6.7            3           5.2          2.3  virginica
# 147  147.0           6.3          2.5             5          1.9  virginica
# 148  148.0           6.5            3           5.2            2  virginica
# 149  149.0           6.2          3.4           5.4          2.3  virginica
# 150  150.0           NaN            3           5.1          1.8  virginica
#
# [151 rows x 6 columns]

# %%
data=pd.read_csv(r'/content/iris_dirty.csv',usecols=['Sepal.Length','Sepal.Width','Petal.Length','Petal.Width','Species'])
data
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             NaN          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           NaN          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
data=pd.read_csv(r'/content/iris_dirty.csv',skiprows=list(range(0,5)))
data
# Out:
#        5   NA  3.6  1.4  0.2     setosa
# 0      6  5.4  NaN  1.7  0.4     setosa
# 1      7  4.6  3.4  1.4  0.3     setosa
# 2      8  5.0  3.4  1.5  0.2     SETOSA
# 3      9  4.4  2.9  1.4  0.2     setosa
# 4     10  4.9  NaN  1.5  0.1     setosa
# ..   ...  ...  ...  ...  ...        ...
# 140  146  6.7  3.0  5.2  2.3  virginica
# 141  147  6.3  2.5  5.0  1.9  virginica
# 142  148  6.5  3.0  5.2  2.0  virginica
# 143  149  6.2  3.4  5.4  2.3  virginica
# 144  150  NaN  3.0  5.1  1.8  virginica
#
# [145 rows x 6 columns]

# %%
data=pd.read_csv(r'/content/iris_dirty.csv',skiprows=5)
data
# Out:
#        5   NA  3.6  1.4  0.2     setosa
# 0      6  5.4  NaN  1.7  0.4     setosa
# 1      7  4.6  3.4  1.4  0.3     setosa
# 2      8  5.0  3.4  1.5  0.2     SETOSA
# 3      9  4.4  2.9  1.4  0.2     setosa
# 4     10  4.9  NaN  1.5  0.1     setosa
# ..   ...  ...  ...  ...  ...        ...
# 140  146  6.7  3.0  5.2  2.3  virginica
# 141  147  6.3  2.5  5.0  1.9  virginica
# 142  148  6.5  3.0  5.2  2.0  virginica
# 143  149  6.2  3.4  5.4  2.3  virginica
# 144  150  NaN  3.0  5.1  1.8  virginica
#
# [145 rows x 6 columns]

# %%
data=pd.read_csv(r'/content/iris_dirty.csv')
data.head()
# Out:
#    Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           1           5.1          3.5           1.4          0.2  Setosa
# 1           2           4.9          3.0           1.4          0.2  setosa
# 2           3           4.7          3.2           1.3          0.2  setosa
# 3           4           4.6          3.1           1.5          0.2  setosa
# 4           5           NaN          3.6           1.4          0.2  setosa

# %%
data.head(3)
# Out:
#    Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           1           5.1          3.5           1.4          0.2  Setosa
# 1           2           4.9          3.0           1.4          0.2  setosa
# 2           3           4.7          3.2           1.3          0.2  setosa

# %%
data.head(10)
# Out:
#    Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           1           5.1          3.5           1.4          0.2  Setosa
# 1           2           4.9          3.0           1.4          0.2  setosa
# 2           3           4.7          3.2           1.3          0.2  setosa
# 3           4           4.6          3.1           1.5          0.2  setosa
# 4           5           NaN          3.6           1.4          0.2  setosa
# 5           6           5.4          NaN           1.7          0.4  setosa
# 6           7           4.6          3.4           1.4          0.3  setosa
# 7           8           5.0          3.4           1.5          0.2  SETOSA
# 8           9           4.4          2.9           1.4          0.2  setosa
# 9          10           4.9          NaN           1.5          0.1  setosa

# %%
data.tail() #will display last rows
# Out:
#      Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  \
# 145         146           6.7          3.0           5.2          2.3
# 146         147           6.3          2.5           5.0          1.9
# 147         148           6.5          3.0           5.2          2.0
# 148         149           6.2          3.4           5.4          2.3
# 149         150           NaN          3.0           5.1          1.8
#
#        Species
# 145  virginica
# 146  virginica
# 147  virginica
# 148  virginica
# 149  virginica

# %%
data.tail(3)
# Out:
#      Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  \
# 147         148           6.5          3.0           5.2          2.0
# 148         149           6.2          3.4           5.4          2.3
# 149         150           NaN          3.0           5.1          1.8
#
#        Species
# 147  virginica
# 148  virginica
# 149  virginica

# %%
data.tail(10)
# Out:
#      Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  \
# 140         141           6.7          3.1           5.6          2.4
# 141         142           6.9          3.1           5.1          2.3
# 142         143           NaN          2.7           5.1          1.9
# 143         144           6.8          NaN           5.9          2.3
# 144         145           NaN          3.3           5.7          2.5
# 145         146           6.7          3.0           5.2          2.3
# 146         147           6.3          2.5           5.0          1.9
# 147         148           6.5          3.0           5.2          2.0
# 148         149           6.2          3.4           5.4          2.3
# 149         150           NaN          3.0           5.1          1.8
#
#        Species
# 140  virginica
# 141  virginica
# 142  virginica
# 143  virginica
# 144  virginica
# 145  virginica
# 146  virginica
# 147  virginica
# 148  virginica
# 149  virginica
